# %% [markdown]
# ### *АВТ-910_РГЗ_Безденежных_Васильев?*
#
# ## Цель работы
# Знакомство элементами технологии создания баз знаний интеллектуальных систем.
#
# ## Задачи
# - Освоение способа сохранения и загрузки обученных моделей машинного обучения;
# - Разработка интерфейса доступа к сохраненным моделям;
# - Организация произвольных запросов с использованием разработанного интерфейса.
#
# Используемые программные инструменты:
# - Язык программирования: python
# - Реализация алгоритмов машинного обучения: tensorflow, sklearn
# - Сериализация/десериализация: json, pickle, tensorflow
# - web-интерфейс: streamlit
#
# ## Ход работы
# 1. Выполнить загрузку файла с подготовленным набором данных (очищенный от пропусков и выбросов для целевой и независимых переменных) в таблицу <u>исходных данных df</u>
# 2. Объявить список названий целевых (target) и независимой (features) переменных
# 3. Отделить X от Y исходной таблицы и сформировать новые таблицы dfX и dfY
# 4. Выполнить процедуру НОРМАЛИЗАЦИИ данных и сохранить в отдельную таблиц
#     1. Используя класс MinMaxScaler создать отдельные объекты-шкалёры <u>scalerNormForX</u> и <u>scalerNormForY</u> для выполнения нормализации для целевой и независимых переменных
#     2. Используя класс MinMaxScaler получить нормализованные версии <u>dfX</u> и <u>dfY</u> и сохранить их в <u>dfXNorm</u> и <u>dfYNorm</u> соответственно
# 5. Сформировать обучающую и проверочную части
#     1. На основе исходных данных <u>dfX</u> и <u>dfY</u> сформировать <u>xTrain , xTest , yTrain , yTest</u>
#     2. На основе нормализованной выборки  <u>dfXNorm</u> и <u>dfYNorm</u> сформировать <u>xNormTrain, xNormTest, yNormTrain, yNormTest</u>
# 6. Модель m1. Линейная регрессия
#     1. Для построения линейной регрессионной модели выбрать из <u>dfX</u> группу  независимых признаков 'x1, x2, x3, ...'
#     2. Создать и обучить на выбранных признаках модель LinearRegression() из библиотеки sklearn, используя <u>xTrain</u>, <u>yTrain</u>
#     3. Получить вычисленные значения <u>yPred</u> с использованием обученной модели на  данных <u>xTest</u>
#     4. Получить оценки точности R2, RMSE для построенной модели, используя данные  <u>yPred</u> и <u>yTest</u>
# 7. Модель m2. Нейронная сеть
#     1. Выбрать из <u>dfNormX</u> группу  независимых признаков 'x1, x2, x3, ...'
#     2. Определить
#         1. Структуру одной моделей (кол-во узлов на входных, выходных и скрытых слоях и узлов на каждом из слоев).
#         2. Вид нелинейных функции активации для скрытых слоев
#         3. Функцию оценки потерь (способ оценки ошибок между <u>yNormPred</u> и <u>yTrain</u>)
#         4. Функцию оптимизации
#     3. Создать модель, используя библиотеку tensorflow
#     4. Обучить модель на выбранных признаках, используя нормализованные данные <u>xNormTrain</u>, <u>yNormTrain</u>
#     5. Получить вычисленные значения <u>yNormPred</u> с использованием обученной модели на  нормализованных данных <u>xNormTest </u>
#     6. Получить оценки точности R2, RMSE для построенной модели, используя  нормализованные данные  <u>yNormPred</u> и <u>yNormTest</u>
# 8. Сохранение моделей. Для обученных моделей (m1, m2, …):
#     1. Заполните следующие характеристики модели в структуре типа “ключ-значение”, где “ключ” название характеристики:
#         * Тип модели
#         * Требует нормализованные данные
#         * Название признаков входных
#         * Название признаков выходных
#         * R2
#         * RMSE
#         * Выбранные вами дополнительные характеристики …
#     2. Сохраните структуру типа “ключ-значение” в файле формата JSON, используя команду  json.dump(...)
#     3. Для m2 сохраните объекты-шкалеры <u>scalerNormForX</u> и <u>scalerNormForY</u> с помощью механизма сериализации в файл, используя команду  pickle.dump(...)
#     4. Сохраните обученные модели с помощью механизма сериализации в файл:
#         1. Для моделей m1 используйте команду  pickle.dump(...)
#         2. Для моделей m2 используйте команду  tensorflow.save(...)
# 9. Загрузка и опрос обученных моделей в среде JupyterLab
#     1. Создайте новый файл JupyterLab  (*ipynb)
#     2. Изучите и проверьте все функции, необходимые для загрузки (десериализации) объектов
#     3. Создайте таблицу pandas.DataFrame c единственной строкой и произвольными значениями.
#     4. Проверьте работу функций fit, transform, inverse_transform у объекта шкалёра для созданной таблицы pandas.DataFrame
#     5. Проверьте работу функции вычисления ответа от обученной модели (функция predict)
# 10. Разработка web-интерфейса
#     1. Для каждой из независимых (features) переменных подберите подходящий способ ввода значений из доступных в библиотеке streamlit
#     2. Создайте проект web-страницы и расположите элементы интерфейса для ввода значений независимых (features) переменных и вывода вычисленных значений целевой (target)
# 11. Загрузка и опрос обученных моделей в созданном  web-интерфейсе
#     1. В созданном проекте web-страницы загрузите все объекты сохраненные в п.8 с учетом формата сохранения
#     2. Организуйте передачу введенных на web-странице значений (независимых (features) переменных) в функцию вычисления ответа у загруженных моделей
#         1. Получить введенные значения и преобразовать их в таблицу данных типа pandas.DataFrame. Таблица будет содержать единственную строку.
#         2. Создайте таблицу данных типа pandas.DataFrame с нормализованной версией введенных значений, используя объект-шкалёра <u>scalerNormForX</u>. Таблица будет содержать единственную строку.
#         3. Для получения вычисленного ответа передайте в функцию .predict(...) загруженных моделей соответствующую таблицу
#     3. Отобразите на web-странице вычисленные ответы от каждой модели. При необходимости выполните денормализацию вычисленных значений ответа с использованием объекта-шкалёра <u>scalerNormForY</u>
#     4. Отобразите на web-странице характеристики точности R2, RMSE для соответствующих моделей.
# 12. Проверка работоспособности
#     1. Выберите из проверочной части xTest и yTest не менее 3 строк-образцов.
#     2. Введите значения независимых (features) переменных из строк образцов на web-странице и получите вычисленные значения ответа для каждой из них.
#     3. Полученные результаты оформите в виде таблицы в отчете
#
# ![image.png](attachment:image.png)
#
# ## Ссылки на доп материалы
# * [Офф. справка] Библиотека pickle.URL: https://docs.python.org/3/library/pickle.html
# * [Офф. справка] Библиотека json.URL: https://docs.python.org/3/library/json.html
# * [Офф. справка] TensorFlow Сохранение и загрузка моделей.URL: https://www.tensorflow.org/tutorials/keras/save_and_load
# * [Офф. справка] Streamlit. Компоненты страницы для ввода значений.URL: https://docs.streamlit.io/library/api-reference#input-widgets

# %% [markdown]
# Импортируем все модули, требуемые для выполнения работы:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from matplotlib import pyplot as plt

import json
import pickle

# %% [markdown]
# Объявим функции, которые понадобятся нам в будущем несколько раз:

# %%
def GET_METRICS_SINGLE(y_test, y_pred):
    '''
    Вычисление и вывод метрик: MAE, RMSE, R2.
    На основе сравнения проверочных и вычисленных.
    :param y_test: - проверочные значения целевой переменный
    :param y_pred: - вычисленные значения целевой переменный
    '''
    mae  = metrics.mean_absolute_error        (y_test, y_pred)
    mse  = metrics.mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2   = metrics.r2_score                   (y_test, y_pred)

    print ("MAE : {:>9,.3f} (средняя абсолютная ошибка)".format              ( mae ))
    print ("MSE : {:>9,.6f} (среднеквадратичная ошибка)".format( mse ))
    print ("RMSE: {:>9,.6f} (кв. корень из среднеквадратичной ошибки)".format( rmse ))
    print ("R2  : {:>9,.3f} (коэфф. детерминации)".format                    ( r2 ))
#--------------------------------------------------------------------------

# %%
def PLOT34(y_test, y_pred):
    '''
    Функция построения графиков
    :param y_test: - проверочные значения целевой переменный
    :param y_pred: - вычисленные значения целевой переменный
    '''
    plt.figure(figsize=(12,6))
    
    # == Диаграмма рассеяния вычисленных значений ==
    # создать первое полотно 121: 1-строк, 2-столбцов, 1-индекс текущего полотна в сетке
    plt.subplot(121)
    plt.scatter(y_test, y_pred,  alpha=0.1)
    plt.scatter(y_test, y_test,  alpha=0.1)
    plt.title('Диаграмма рассеяния вычисленных значений');
    plt.xlabel('Проверочное Y')
    plt.ylabel('Вычисленное Y')

    
    # == Диаграмма рассеяния ошибок ==
    # создать первое полотно 121: 1-строк, 2-столбцов, 2-индекс текущего полотна в сетке
    plt.subplot(122)
    plt.scatter(y_test, (y_test - y_pred)**2,  alpha=0.1)
    plt.title('Диаграмма рассеяния квадрата абсолютной ошибки')
    plt.xlabel('Проверочное Y')
    plt.ylabel('Квадрат абсолютной ошибки')
#--------------------------------------------------------------------------

# %% [markdown]
# Загрузим файл с подготовленным набором данных из прошлых работ:

# %%
df = pd.read_csv('./assets/datasets/var20/bike-sharing-dataset_nan_PREPARED.csv', sep=',', header=0)

# %% [markdown]
# Объявим список названий целевых (target) и независимой (features) переменных из наших прошлых работ.

# %%
features = ['temp', 'hr', 'weekday',  'mnth', 'season', 'hum', 'weathersit']
target = ['cnt']

# %% [markdown]
# Отделим X от Y и сформируем новые таблицы <u>dfX</u> и <u>dfY</u>

# %%
dfX = df[features]
dfY = df[target]

# %% [markdown]
# Выполним процедуру нормализации данных и сохраним результат в 2 отдельные таблицы <u>dfXNorm</u> и <u>dfYNorm</u>

# %%
scalerNormForX = MinMaxScaler()
scalerNormForY = MinMaxScaler()

dfXNorm = pd.DataFrame(data=scalerNormForX.fit_transform(dfX), columns=dfX.columns, index=dfX.index)
dfYNorm = pd.DataFrame(data=scalerNormForY.fit_transform(dfY), columns=dfY.columns, index=dfY.index)

# %% [markdown]
# Построим гистограммы по каждому признаку

# %%
plt.figure(figsize=(16, 5))
plot_number = 0
for feature_name in (features+target):
    plot_number += 1
    plt.subplot(1, len(features+target), plot_number)
    plt.hist(df[feature_name]) # Построение гистрограммы
    plt.title(feature_name)
    plt.xlabel(u'Значения')
    plt.ylabel(u'Частота')
    print(feature_name, 
          df[feature_name].min(),
          df[feature_name].max())
# Out:
# temp 0.02 1.0
# hr 0.0 23.0
# weekday 0.0 6.0
# mnth 1.0 12.0
# season 1.0 4.0
# hum 0.1 1.0
# weathersit 1.0 4.0
# cnt 1.0 625.0

# %% [markdown]
# Сформируем обучающую и проверочную части. Сначала для исходной выборки, затем для нормализованной.

# %%
rand_seed = 8
valid_size = 0.3
xTrain, xTest, yTrain, yTest = train_test_split(
    dfX, dfY, test_size=valid_size, random_state=rand_seed, shuffle=True)

xNormTrain, xNormTest, yNormTrain, yNormTest = train_test_split(
    dfXNorm, dfYNorm, test_size=valid_size, random_state=rand_seed, shuffle=True)

# %% [markdown]
# Для построения линейной регрессионной модели выберем из dfX группу независимых признаков 'x1, x2, x3, ...'. Возьмём те же признаки, что и в прошлых ЛР.

# %%
lr = LinearRegression()
m1 = lr.fit(
    xTrain[['season', 'hum', 'weathersit']], 
    yTrain[['cnt']]
)
yPred = m1.predict(xTest[['season', 'hum', 'weathersit']])

# %% [markdown]
# Получим оценки точности R2, RMSE для построенной модели, используя данные <u>yPred</u> и <u>yTest</u>

# %%
GET_METRICS_SINGLE(yTest, yPred)
print(f"Линейная одномерная регрессия. Признаки 'season', 'hum', 'weathersit'.")
print(f'yPred (x) = x * {m1.coef_} + {m1.intercept_}\n')
# Out:
# MAE :   109.303 (средняя абсолютная ошибка)
# MSE : 18,973.977307 (среднеквадратичная ошибка)
# RMSE: 137.746061 (кв. корень из среднеквадратичной ошибки)
# R2  :     0.165 (коэфф. детерминации)
# Линейная одномерная регрессия. Признаки 'season', 'hum', 'weathersit'.
# yPred (x) = x * [[  31.57159194 -301.92975955    7.19964691]] + [273.40294162]

# %% [markdown]
# Графики линейной регрессии:

# %%
plt.figure(figsize=(6,4))
sns.histplot(yTest[['cnt']] - yPred, color="red", kde=True, stat="density")
plt.plot([0, 0], [0, 10 * pow(10,-7)], '--', lw=2, c='r')
plt.ylabel(u'Плотность')
plt.xlabel(u'Значение ошибки')
plt.title(u'Плотность распределения и гистограмма ошибок');
plt.show()

# %%
PLOT34(yTest, yPred)

# %% [markdown]
# Сохраним числовые характеристики в отдельные переменные для будущего сохранения в файл

# %%
m1_r2 = metrics.r2_score(yTest, yPred)
m1_rmse = np.sqrt(metrics.mean_squared_error(yTest, yPred))

# %% [markdown]
# Построим модель при помощи нейронной сети. Выберем из dfNormX группу независимых признаков 'x1, x2, x3, ...' (те же признаки, что и в 3 ЛР). Будем использовать скрытые слои.

# %%
with tf.device('/CPU:0'):
    totalHistoryLossTrain=[]
    totalHistoryLossTest=[]
    input_size  = 5
    output_size = 1
    m2 = tf.keras.models.Sequential()
    # Слои НС
    m2.add(tf.keras.layers.Input(shape=(input_size)))
    m2.add(tf.keras.layers.Dense(units=25, activation=tf.keras.activations.relu))
    m2.add(tf.keras.layers.Dense(units=10, activation=tf.keras.activations.relu))
    m2.add(tf.keras.layers.Dense(units=input_size, activation=tf.keras.activations.relu))
    m2.add(tf.keras.layers.Dense(units=output_size, activation=tf.keras.activations.linear))
    
    fLoss = tf.keras.losses.mean_squared_error
    fOptimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
    fMetric = [tf.keras.losses.mean_squared_error]
    m2.compile(
        loss=fLoss, 
        optimizer=fOptimizer, 
        metrics=[fMetric])

# %%
epochForTrain = 100

with tf.device('/CPU:0'):
    history = m2.fit(
        xNormTrain[['temp', 'hr', 'weekday',  'mnth', 'season']],
        yNormTrain,
        validation_data=(xNormTest[['temp', 'hr', 'weekday',  'mnth', 'season']], yNormTest),
        epochs=epochForTrain,
        verbose=1)
    totalHistoryLossTrain.extend(history.history['loss'])
    if 'val_loss' in history.history.keys():
        totalHistoryLossTest.extend(history.history['val_loss'])
# Out:
# Epoch 1/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0386 - mean_squared_error: 0.0386 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Epoch 2/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 3/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 4/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0259 - mean_squared_error: 0.0259 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 5/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 6/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 7/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# Epoch 8/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 9/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 10/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 11/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 12/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 13/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 14/100
# 361/361 [==============================] - 1s 3ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 15/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 16/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 17/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 18/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 19/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 20/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 21/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 22/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 23/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 24/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 25/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 26/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 27/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 28/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 29/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 30/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 31/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0193 - val_mean_squared_error: 0.0193
# Epoch 32/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 33/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 34/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 35/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 36/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 37/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 38/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 39/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 40/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 41/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 42/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 43/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 44/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 45/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 46/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 47/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 48/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 49/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 50/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 51/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 52/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 53/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 54/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 55/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 56/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 57/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 58/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 59/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 60/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 61/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 62/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 63/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 64/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 65/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 66/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 67/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 68/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 69/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 70/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 71/100
# 361/361 [==============================] - 1s 3ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 72/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 73/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 74/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 75/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 76/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 77/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 78/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 79/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 80/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 81/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 82/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 83/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 84/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 85/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 86/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 87/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 88/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 89/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 90/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 91/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 92/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 93/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 94/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 95/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 96/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 97/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 98/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 99/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 100/100
# 361/361 [==============================] - 1s 2ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0152 - val_mean_squared_error: 0.0152

# %%
plt.plot(totalHistoryLossTrain, label='train')
if 'val_loss' in history.history.keys():
    plt.plot(totalHistoryLossTest, label='test')
plt.legend()
plt.title("История изменений выбраной оценки потерь (LossVal = mean_squared_error)")
plt.ylabel("Оценка потерь (mean_squared_error)")
plt.xlabel("Эпохи обучения")
# Out:
# Text(0.5, 0, 'Эпохи обучения')

# %%
with tf.device('/CPU:0'):
    yNormPred = m2.predict(xNormTest[['temp', 'hr', 'weekday', 'mnth', 'season']])
GET_METRICS_SINGLE(yNormTest, yNormPred)
PLOT34(yNormTest, yNormPred)
# Out:
# 155/155 [==============================] - 0s 881us/step
# MAE :     0.087 (средняя абсолютная ошибка)
# MSE :  0.015170 (среднеквадратичная ошибка)
# RMSE:  0.123168 (кв. корень из среднеквадратичной ошибки)
# R2  :     0.740 (коэфф. детерминации)

# %%
m2_r2 = metrics.r2_score(yNormTest, yNormPred)
m2_rmse = np.sqrt(metrics.mean_squared_error(yNormTest, yNormPred))

# %% [markdown]
# Сохраним дополнительные данные о наших моделях в формате JSON.

# %%
# Создание словарей с данными о моделях
m1_info = dict()
m1_info['m2_type'] = str(type(m1))
m1_info['requires_normalised_data'] = False
m1_info['features'] = ['season', 'hum', 'weathersit']
m1_info['target'] = target
m1_info['R2'] = m1_r2
m1_info['RMSE'] = m1_rmse

m2_info = dict()
m2_info['m2_type'] = str(type(m2))
m2_info['requires_normalised_data'] = True
m2_info['features'] = ['temp', 'hr', 'weekday', 'mnth', 'season']
m2_info['target'] = target
m2_info['R2'] = m2_r2
m2_info['RMSE'] = m2_rmse

# Сохранение словарей в формате JSON
with open(r'./assets/dump/m1_info.json', 'w', encoding='utf-8') as filestream:
    json.dump(m1_info, filestream, indent=4)
with open(r'./assets/dump/m2_info.json', 'w', encoding='utf-8') as filestream:
    json.dump(m2_info, filestream, indent=4)

# %% [markdown]
# Сохраним модель m1 и модель m2, а также объекты-шкалёры

# %%
# Сохранение объектов-шкалёров
with open(r'./assets/dump/scalerNormForX.txt', 'wb') as filestream:
    pickle.dump(scalerNormForX, filestream)
with open(r'./assets/dump/scalerNormForY.txt', 'wb') as filestream:
    pickle.dump(scalerNormForY, filestream)
# Сохранение моделей
with open(r'./assets/dump/m1.txt', 'wb') as filestream:
    pickle.dump(m1, filestream)
m2.save(r'./assets/dump/m2.txt', overwrite=True, save_format='h5')

# %% [markdown]
# Загрузку наших моделей будем осуществлять уже в другом файле (RGZ-2).
